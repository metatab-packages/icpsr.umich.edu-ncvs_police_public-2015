# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# `icpsr.umich.edu-ncvs_police_public-2015-1.1.1` Last Update: 2020-06-11T16:09:47
#
# __
#
#
# This dataset processed the ICPSR dataset for the 2015 Police to Public Contact
# Survey. Using the source dataset requires accepting an agreement that restrict
# re-publication, so this dataset should not be published. Therefore, it can only
# be used as a source dataset.
#
# To use this source dataset:
#
# 1. [Download the source from ICPSR](https://www.icpsr.umich.edu/icpsrweb/NACJD/studies/36653#) and put the ZIP file into the `data/` directory in this package
# 2. Unzip the ZIP file.
# 3. Build this package with `mp build` or `mp make`
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
#
# ## References
# <ul><li> <strong>source</string>, <em>data/ICPSR_36653/DS0001/36653-0001-Data.dta</em>. Source datafile</li><ul>

# %%
path = pkg.reference('source').resolved_url.fspath

df = pd.read_stata(path)
len(df)
# Out:
# 90719

# %%
df
# Out:
#                    SCRMCTRL  SAMPLE     PPCSWGT  SEQNUM     SEX  AGE  \
# 0      01209393741537595885      26  3766.95078       1  Female   34
# 1      01209393741537595885      26  3573.70517       2    Male   49
# 2      01882029586028596013      26  3890.03999       3  Female   47
# 3      01882029586028596013      26  3823.52546       4    Male   48
# 4      04040420678447911089      26  3142.60112       5    Male   62
# ...                     ...     ...         ...     ...     ...  ...
# 90714  46999998573753383299      28  1767.04789   90715    Male   64
# 90715  46999998573753383299      28     0.00000   90716    Male   63
# 90716  46999998627438363208      28  2053.04208   90717  Female   65
# 90717  46999998849982343299      28  1579.17787   90718  Female   49
# 90718  46999998849982343299      28  1719.21591   90719    Male   49
#
#                                  HISP         INTTYPE           NONINT  \
# 0      No, respondent is not Hispanic  Telephone-Self  Out of universe
# 1      No, respondent is not Hispanic  Telephone-Self  Out of universe
# 2         Yes, respondent is Hispanic  Telephone-Self  Out of universe
# 3         Yes, respondent is Hispanic  Telephone-Self  Out of universe
# 4      No, respondent is not Hispanic  Telephone-Self  Out of universe
# ...                               ...             ...              ...
# 90714  No, respondent is not Hispanic  Telephone-Self  Out of universe
# 90715  No, respondent is not Hispanic    Noninterview      NCVS Type Z
# 90716  No, respondent is not Hispanic   Personal-Self  Out of universe
# 90717  No, respondent is not Hispanic   Personal-Self  Out of universe
# 90718  No, respondent is not Hispanic   Personal-Self  Out of universe
#
#              RACE  ... V360 V361  V362  V363               V364  \
# 0      White Only  ...   No   No    No    No  No contact or out
# 1      White Only  ...   No   No    No    No            Contact
# 2      White Only  ...   No   No    No    No  No contact or out
# 3      White Only  ...   No   No    No    No  No contact or out
# 4      White Only  ...   No   No    No    No  No contact or out
# ...           ...  ...  ...  ...   ...   ...                ...
# 90714  Black Only  ...   No   No    No    No  No contact or out
# 90715  Black Only  ...   No   No    No    No  No contact or out
# 90716  Asian Only  ...   No   No    No    No            Contact
# 90717  White Only  ...   No   No    No    No            Contact
# 90718  White Only  ...   No   No    No    No            Contact
#
#                     V365               V366                V367  \
# 0      No contact or out  No contact or out     No MRC reported
# 1             RI Contact  No contact or out      Reported crime
# 2      No contact or out  No contact or out     No MRC reported
# 3      No contact or out  No contact or out     No MRC reported
# 4      No contact or out  No contact or out     No MRC reported
# ...                  ...                ...                 ...
# 90714  No contact or out  No contact or out     No MRC reported
# 90715  No contact or out  No contact or out     Out of universe
# 90716         RI Contact         PI Contact      Reported crime
# 90717         RI Contact  No contact or out  Reported non-crime
# 90718         RI Contact         PI Contact    Traffic accident
#
#                     V368               V369
# 0      No contact or out  No contact or out
# 1                 RI MRC  No contact or out
# 2      No contact or out  No contact or out
# 3      No contact or out  No contact or out
# 4      No contact or out  No contact or out
# ...                  ...                ...
# 90714  No contact or out  No contact or out
# 90715  No contact or out  No contact or out
# 90716             RI MRC  No contact or out
# 90717             RI MRC  No contact or out
# 90718  No contact or out  No contact or out
#
# [90719 rows x 423 columns]
