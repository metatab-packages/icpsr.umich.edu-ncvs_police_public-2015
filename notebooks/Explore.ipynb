# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Police-Public Contact Survey, 2015
# `icpsr.umich.edu-ncvs_police_public-2015-1.1.1` Last Update: 2020-06-11T16:09:47
#
# _Microdata for the BJS Police-Public Contact Survey, 2015_
#
#
# This dataset processed the ICPSR dataset for the 2015 Police to Public Contact
# Survey. Using the source dataset requires accepting an agreement that restrict
# re-publication, so this dataset should not be published. Therefore, it can only
# be used as a source dataset.
#
# To use this source dataset:
#
# 1. [Download the source from ICPSR](https://www.icpsr.umich.edu/icpsrweb/NACJD/studies/36653#) and put the ZIP file into the `data/` directory in this package
# 2. Unzip the ZIP file.
# 3. Build this package with `mp build` or `mp make`
# ## Documentation Links
#
# * [Published Analyses](https://www.icpsr.umich.edu/icpsrweb/NACJD/studies/36653/publications) ICPSR List of papers that reference this dataset
# * [An Empirical Analysis of Racial Di↵erences in Police Use of Force](https://scholar.harvard.edu/files/fryer/files/empirical_analysis_tables_figures.pdf) A research paper from Roland Fryer that uses this dataset
# * [Home Page](https://www.bjs.gov/index.cfm?ty=pbdetail&iid=6406) ome page for the survey suplement
# * [ICSPR Download Page](https://www.icpsr.umich.edu/icpsrweb/NACJD/studies/36653#) Home page for downloading the full dataset.
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
#
# ## References
# <ul><li> <strong>source</string>, <em>data/ICPSR_36653/DS0001/36653-0001-Data.dta</em>. Source datafile</li><ul>

# %%
path = pkg.reference('source').resolved_url.fspath

df = pd.read_stata(path)
len(df)
# Out:
# 90719

# %%
df.head().T
# Out:
#                              0                     1                     2  \
# SCRMCTRL  01209393741537595885  01209393741537595885  01882029586028596013
# SAMPLE                      26                    26                    26
# PPCSWGT                3766.95               3573.71               3890.04
# SEQNUM                       1                     2                     3
# SEX                     Female                  Male                Female
# ...                        ...                   ...                   ...
# V365         No contact or out            RI Contact     No contact or out
# V366         No contact or out     No contact or out     No contact or out
# V367           No MRC reported        Reported crime       No MRC reported
# V368         No contact or out                RI MRC     No contact or out
# V369         No contact or out     No contact or out     No contact or out
#
#                              3                     4
# SCRMCTRL  01882029586028596013  04040420678447911089
# SAMPLE                      26                    26
# PPCSWGT                3823.53                3142.6
# SEQNUM                       4                     5
# SEX                       Male                  Male
# ...                        ...                   ...
# V365         No contact or out     No contact or out
# V366         No contact or out     No contact or out
# V367           No MRC reported       No MRC reported
# V368         No contact or out     No contact or out
# V369         No contact or out     No contact or out
#
# [423 rows x 5 columns]

# %%
list(df.columns)
# Out:
# ['SCRMCTRL',
#  'SAMPLE',
#  'PPCSWGT',
#  'SEQNUM',
#  'SEX',
#  'AGE',
#  'HISP',
#  'INTTYPE',
#  'NONINT',
#  'RACE',
#  'MODE',
#  'CBSA',
#  'PSSTRATA',
#  'SECUCODE',
#  'WORK',
#  'INCOME',
#  'PLACE',
#  'V1',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V10A',
#  'V10B',
#  'V10C',
#  'V10D',
#  'V10E',
#  'V10F',
#  'V10G',
#  'V10H',
#  'V10I',
#  'V10J',
#  'V10K',
#  'V10L',
#  'V10M',
#  'V10N',
#  'V10O',
#  'V10P',
#  'V10Q',
#  'V10R',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V22A',
#  'V22B',
#  'V22C',
#  'V22D',
#  'V22E',
#  'V22F',
#  'V22G',
#  'V22H',
#  'V22I',
#  'V22J',
#  'V22K',
#  'V22L',
#  'V22M',
#  'V22N',
#  'V22O',
#  'CHECK_ITEM_A',
#  'CHECK_ITEM_A1',
#  'CHECK_ITEM_A2',
#  'CHECK_ITEM_A3',
#  'CHECK_ITEM_B',
#  'CHECK_ITEM_B1A',
#  'CHECK_ITEM_B1B',
#  'CHECK_ITEM_B1C',
#  'CHECK_ITEM_B1D',
#  'CHECK_ITEM_B1E',
#  'CHECK_ITEM_B1F',
#  'CHECK_ITEM_B1G',
#  'CHECK_ITEM_B1H',
#  'CHECK_ITEM_B1I',
#  'CHECK_ITEM_B1J',
#  'V23A',
#  'V23B',
#  'V23C',
#  'V23D',
#  'V23E',
#  'V23F',
#  'V23G',
#  'V23H',
#  'V23I',
#  'V23J',
#  'V23K',
#  'V23L',
#  'V23M',
#  'V23N',
#  'V23O',
#  'V23P',
#  'V23Q',
#  'V23R',
#  'V23S',
#  'V23T',
#  'V23U',
#  'V32',
#  'V32A',
#  'CHECK_ITEM_B2A',
#  'CHECK_ITEM_B2B',
#  'CHECK_ITEM_B2C',
#  'CHECK_ITEM_B2D',
#  'CHECK_ITEM_B2E',
#  'CHECK_ITEM_B2F',
#  'CHECK_ITEM_B2G',
#  'CHECK_ITEM_B2H',
#  'CHECK_ITEM_B2I',
#  'CHECK_ITEM_B2J',
#  'V33',
#  'V33A',
#  'V34',
#  'V35',
#  'V36',
#  'V38',
#  'V39',
#  'V40',
#  'V41',
#  'V42',
#  'V43',
#  'V44',
#  'V45',
#  'V46',
#  'V47',
#  'V48',
#  'CHECK_ITEM_C',
#  'V49',
#  'V50',
#  'V51',
#  'V52',
#  'V53',
#  'V54',
#  'V56',
#  'V57',
#  'V58',
#  'V59',
#  'V60',
#  'V61',
#  'V62',
#  'V63',
#  'V64',
#  'V65',
#  'V66',
#  'V67',
#  'V67A',
#  'V68',
#  'V69',
#  'V70',
#  'V71',
#  'V72',
#  'V73',
#  'V74',
#  'V74A',
#  'V74B',
#  'V74C',
#  'V75',
#  'V76',
#  'V77',
#  'V78',
#  'V79',
#  'V80',
#  'CHECK_ITEM_D',
#  'V81',
#  'V85',
#  'V85A',
#  'V86',
#  'V87',
#  'V88',
#  'V89',
#  'V92',
#  'V93',
#  'V138',
#  'V139',
#  'V140',
#  'V141',
#  'V142',
#  'V143',
#  'V144',
#  'V145',
#  'V146',
#  'V147',
#  'V148',
#  'V149',
#  'V150',
#  'V151',
#  'V152',
#  'V153',
#  'V154',
#  'V155',
#  'V156',
#  'V157',
#  'V158',
#  'V159',
#  'V160',
#  'V161',
#  'CHECK_ITEM_E',
#  'V162',
#  'V163',
#  'V164',
#  'V165',
#  'V166',
#  'V167',
#  'V168',
#  'V169',
#  'V170',
#  'V171',
#  'V172',
#  'V173',
#  'V174',
#  'V175',
#  'V176',
#  'V177',
#  'V178',
#  'V179',
#  'CHECK_ITEM_F',
#  'V182',
#  'V183',
#  'V186',
#  'V187',
#  'CHECK_ITEM_G',
#  'V188',
#  'V189_1',
#  'V189_2',
#  'V189',
#  'V189A',
#  'V190',
#  'V191',
#  'V192',
#  'V193',
#  'V194',
#  'V195',
#  'V196',
#  'V197',
#  'V197A',
#  'V197B',
#  'V197C',
#  'V198',
#  'V199',
#  'V200',
#  'V201',
#  'V202',
#  'V203',
#  'CHECK_ITEM_H',
#  'V204',
#  'CHECK_ITEM_I',
#  'V205',
#  'V206',
#  'V210',
#  'V211',
#  'V212',
#  'V213',
#  'V214',
#  'V215',
#  'V216',
#  'V217',
#  'V218',
#  'V219',
#  'V220',
#  'V221',
#  'V222',
#  'V223',
#  'V224',
#  'V225',
#  'V226',
#  'V227',
#  'V228',
#  'V228A',
#  'V229',
#  'V230',
#  'V231',
#  'V232',
#  'V233',
#  'V234',
#  'V235',
#  'V236',
#  'V237',
#  'V238',
#  'V239',
#  'V240',
#  'V241',
#  'V242',
#  'V243',
#  'V244',
#  'V245',
#  'V246',
#  'V247',
#  'V248',
#  'V249_1',
#  'V249_2',
#  'V249',
#  'V249A',
#  'V255',
#  'V256',
#  'V257',
#  'V258',
#  'V259',
#  'V260',
#  'V261',
#  'V263',
#  'V264',
#  'V265',
#  'V266',
#  'V267',
#  'V268',
#  'V269',
#  'V270',
#  'V271',
#  'V272',
#  'V273',
#  'V274',
#  'V275',
#  'V276',
#  'V277',
#  'V278',
#  'V279_1',
#  'V279_2',
#  'V279',
#  'V280',
#  'V281',
#  'V282',
#  'V283',
#  'V284',
#  'V285',
#  'V286',
#  'V287',
#  'V288',
#  'V289',
#  'V290',
#  'V291',
#  'V292',
#  'V293',
#  'V294',
#  'V295',
#  'V296',
#  'V297',
#  'V298',
#  'V299',
#  'V300',
#  'V301',
#  'V302',
#  'V303',
#  'V303A',
#  'CHECK_ITEM_J',
#  'V304',
#  'V305',
#  'V306',
#  'V307',
#  'V308',
#  'V309',
#  'V310',
#  'V311',
#  'V312',
#  'V313',
#  'V314',
#  'V315',
#  'V316',
#  'V317',
#  'V318',
#  'V319',
#  'V320',
#  'V321',
#  'V321A',
#  'CHECK_ITEM_K',
#  'CHECK_ITEM_L',
#  'V324',
#  'V325',
#  'V327',
#  'V332',
#  'V333',
#  'V334',
#  'V335',
#  'CHECK_ITEM_M',
#  'CHECK_ITEM_N',
#  'CHECK_ITEM_O',
#  'V336',
#  'V336A',
#  'V337',
#  'V338',
#  'V339',
#  'V340',
#  'V341',
#  'V342',
#  'V344',
#  'V345',
#  'V346',
#  'V347',
#  'V348',
#  'V349',
#  'V350A',
#  'V350B',
#  'V350C',
#  'V351',
#  'V352',
#  'CHECK_ITEM_P',
#  'CHECK_ITEM_Q',
#  'CHECK_ITEM_R',
#  'V353',
#  'V354',
#  'V355',
#  'V356',
#  'V357',
#  'V358',
#  'V359',
#  'V360',
#  'V361',
#  'V362',
#  'V363',
#  'V364',
#  'V365',
#  'V366',
#  'V367',
#  'V368',
#  'V369']
